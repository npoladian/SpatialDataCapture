# %% [markdown]
# # Data Engineering
# ## Authors: Jonathan Gat and Ivann Schlosser

# %%
# importing libraries
import pandas as pd
import numpy as np
import validators
import re
from sqlalchemy import create_engine

# %% [markdown]
# ## Importing Data

# %%
# reading JSON file
rawJson = pd.read_json("Artworks.json", encoding='utf-8')

# %% [markdown]
# ## Exploring Features

# %%
# shape
rawJson.shape
# Out:
# (138990, 28)

# %%
# what column does the dataframe contain?
rawJson.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ThumbnailURL',
#        'Height (cm)', 'Width (cm)', 'Depth (cm)', 'Weight (kg)',
#        'Diameter (cm)', 'Length (cm)', 'Circumference (cm)',
#        'Duration (sec.)'],
#       dtype='object')

# %%
# how many artworks are curator approved?
rawJson['Cataloged'].value_counts()
# Out:
# Y    84249
# N    54741
# Name: Cataloged, dtype: int64

# %% [markdown]
# ### Are there any invalid nationality values?
# As we can see in the next cell, the following nationality values should be removed from our data set:
# - '' (empty string) - 1677 occurrences
# - Nationality unknown - 1280 occurrences

# %%
# Nationalities
nationalityCheck = rawJson['Nationality'].explode().value_counts()
print('Number of unique values: ',len(nationalityCheck))
print(nationalityCheck.to_string())
# Out:
# Number of unique values:  123
# American               65382
# French                 24224
# German                 10546
# British                 6893
# Russian                 3526
# Italian                 3433
# Spanish                 3240
# Japanese                2947
# Swiss                   2629
# Dutch                   1957
# Argentine               1919
#                         1677
# Belgian                 1533
# Mexican                 1443
# Nationality unknown     1280
# Austrian                1249
# Canadian                1046
# Brazilian                888
# Hungarian                817
# Czech                    812
# Colombian                791
# Chilean                  625
# Polish                   589
# Danish                   588
# Venezuelan               521
# Ivorian                  483
# South African            459
# Israeli                  375
# Chinese                  348
# Swedish                  348
# Australian               279
# Cuban                    245
# Finnish                  242
# Indian                   213
# Norwegian                203
# Croatian                 182
# Portuguese               175
# Yugoslav                 168
# Ukrainian                160
# Uruguayan                158
# Peruvian                 125
# Korean                   108
# Romanian                  86
# Latvian                   82
# Slovak                    79
# Guatemalan                71
# Serbian                   71
# Scottish                  66
# Costa Rican               64
# Lebanese                  64
# Greek                     63
# Icelandic                 61
# Irish                     61
# Egyptian                  61
# Sudanese                  51
# Turkish                   51
# Pakistani                 50
# Luxembourgish             44
# Slovenian                 39
# Thai                      39
# Filipino                  32
# New Zealander             29
# Burkinabe                 26
# Iranian                   26
# Albanian                  25
# Bosnian                   24
# Lithuanian                24
# Congolese                 23
# Malian                    21
# Haitian                   21
# Macedonian                20
# Moroccan                  17
# Nigerian                  17
# Algerian                  17
# Zimbabwean                15
# Georgian                  14
# Puerto Rican              14
# Cameroonian               13
# Tunisian                  13
# Kenyan                    12
# Bulgarian                 12
# Taiwanese                 11
# Cambodian                  8
# Ecuadorian                 7
# Malaysian                  7
# Canadian Inuit             7
# Ethiopian                  6
# Vietnamese                 5
# Czechoslovakian            5
# Emirati                    5
# Ghanaian                   4
# Palestinian                4
# Bolivian                   4
# Welsh                      4
# Panamanian                 4
# Coptic                     3
# Paraguayan                 3
# Beninese                   3
# Bahamian                   3
# Senegalese                 2
# Kyrgyzstani                2
# Estonian                   2
# Bangladeshi                2
# Nicaraguan                 2
# Singaporean                2
# Native American            2
# Namibian                   2
# Kazakhstani                2
# Salvadoran                 2
# Mauritanian                1
# Cypriot                    1
# Syrian                     1
# Guyanese                   1
# Kuwaiti                    1
# Sahrawi                    1
# Azerbaijani                1
# Catalan                    1
# Tanzanian                  1
# Ugandan                    1
# Sierra Leonean             1
# Persian                    1
# Tajik                      1
# Afghan                     1

# %%
# removing invalid nationality values
rawJson['NationalityClean'] = rawJson['Nationality'].apply(
    lambda row: [val for val in row if val not in ['','Nationality unknown']]   
)

# %%
# Did it work?
nationalityCheck = rawJson['NationalityClean'].explode().value_counts()
print('Number of unique values: ',len(nationalityCheck))
print(nationalityCheck.to_string())
# Out:
# Number of unique values:  121
# American           65382
# French             24224
# German             10546
# British             6893
# Russian             3526
# Italian             3433
# Spanish             3240
# Japanese            2947
# Swiss               2629
# Dutch               1957
# Argentine           1919
# Belgian             1533
# Mexican             1443
# Austrian            1249
# Canadian            1046
# Brazilian            888
# Hungarian            817
# Czech                812
# Colombian            791
# Chilean              625
# Polish               589
# Danish               588
# Venezuelan           521
# Ivorian              483
# South African        459
# Israeli              375
# Chinese              348
# Swedish              348
# Australian           279
# Cuban                245
# Finnish              242
# Indian               213
# Norwegian            203
# Croatian             182
# Portuguese           175
# Yugoslav             168
# Ukrainian            160
# Uruguayan            158
# Peruvian             125
# Korean               108
# Romanian              86
# Latvian               82
# Slovak                79
# Serbian               71
# Guatemalan            71
# Scottish              66
# Lebanese              64
# Costa Rican           64
# Greek                 63
# Egyptian              61
# Icelandic             61
# Irish                 61
# Turkish               51
# Sudanese              51
# Pakistani             50
# Luxembourgish         44
# Slovenian             39
# Thai                  39
# Filipino              32
# New Zealander         29
# Iranian               26
# Burkinabe             26
# Albanian              25
# Bosnian               24
# Lithuanian            24
# Congolese             23
# Haitian               21
# Malian                21
# Macedonian            20
# Moroccan              17
# Nigerian              17
# Algerian              17
# Zimbabwean            15
# Georgian              14
# Puerto Rican          14
# Cameroonian           13
# Tunisian              13
# Bulgarian             12
# Kenyan                12
# Taiwanese             11
# Cambodian              8
# Ecuadorian             7
# Canadian Inuit         7
# Malaysian              7
# Ethiopian              6
# Czechoslovakian        5
# Vietnamese             5
# Emirati                5
# Welsh                  4
# Bolivian               4
# Panamanian             4
# Ghanaian               4
# Palestinian            4
# Beninese               3
# Bahamian               3
# Paraguayan             3
# Coptic                 3
# Namibian               2
# Estonian               2
# Bangladeshi            2
# Salvadoran             2
# Nicaraguan             2
# Kazakhstani            2
# Senegalese             2
# Kyrgyzstani            2
# Native American        2
# Singaporean            2
# Syrian                 1
# Cypriot                1
# Sahrawi                1
# Azerbaijani            1
# Guyanese               1
# Catalan                1
# Tanzanian              1
# Tajik                  1
# Afghan                 1
# Ugandan                1
# Sierra Leonean         1
# Persian                1
# Kuwaiti                1
# Mauritanian            1

# %% [markdown]
# ### Amending nationality values
# Some nationality values do not match any of the nationality values in the `countries` dataset and need to be amended. We address this issue by:
# 1. Loading the `countries` data set into the notebook, eliminating nationality values that occur more than once
# 2. Locating all of the nationality values within the artworks (`rawJson`) data set that do not match any of values in the `countries` data set
# 3. Creating a a new dictionary, each element holds the old nationality value as a key and the correspondent nationality as a value
# 4. Iterating over each row in the `rawJson` data frame and replace any occurrences of the dictionary's keys with the dictionary's values

# %% [markdown]
# #### Step 1: Loading an cleaning the countries data set

# %%
# reading the country csv file
countries_header = ['countryName',
                   'countryCode',
                   'capitalName',
                   'capitalLat',
                   'capitalLong',
                    'continentName',
                   'nationality',
                   'nationality2',
                   'nationality3',
                   'nationality4']

countries = pd.read_csv('bubbleMap.csv',
                        header = None,
                        skiprows = 1,
                        names = countries_header)

countries.head()
# Out:
#       countryName countryCode capitalName  capitalLat  capitalLong  \
# 0     Afghanistan          AF       Kabul   34.516667    69.183333
# 1   Aland Islands          AX   Mariehamn   60.116667    19.900000
# 2         Albania          AL      Tirana   41.316667    19.816667
# 3         Algeria          DZ     Algiers   36.750000     3.050000
# 4  American Samoa          AS   Pago Pago  -14.266667  -170.700000
#
#   continentName      nationality nationality2 nationality3 nationality4
# 0          Asia           Afghan          NaN          NaN          NaN
# 1        Europe     Åland Island          NaN          NaN          NaN
# 2        Europe         Albanian          NaN          NaN          NaN
# 3        Africa         Algerian          NaN          NaN          NaN
# 4     Australia  American Samoan          NaN          NaN          NaN

# %% [markdown]
# Since nationality / country is a one-to-one relationship, the nationality value must be unique.

# %%
# counting the nationality values
nationalityCount = countries['nationality'].value_counts()
nationalityCount = nationalityCount[nationalityCount>1]
print(nationalityCount)
# Out:
# American          3
# Cypriot           2
# Channel Island    2
# Somali            2
# Dominican         2
# Micronesian       2
# Name: nationality, dtype: int64

# %%
# which countries are correspondent with these values?
countries[countries['nationality'].isin(nationalityCount.index)]
# Out:
#                         countryName countryCode       capitalName  capitalLat  \
# 55                           Cyprus          CY           Nicosia   35.166667
# 60                         Dominica          DM            Roseau   15.300000
# 61               Dominican Republic          DO     Santo Domingo   18.466667
# 71   Federated States of Micronesia          FM           Palikir    6.916667
# 88                           Guinea          GN           Conakry    9.500000
# 107                          Jersey          JE      Saint Helier   49.183333
# 138                        Mongolia          MN       Ulaanbaatar   47.916667
# 156                 Northern Cyprus         NaN     North Nicosia   35.183333
# 197                         Somalia          SO         Mogadishu    2.066667
# 198                      Somaliland         NaN          Hargeisa    9.550000
# 231                   United States          US  Washington, D.C.   38.883333
# 233       US Minor Outlying Islands          UM  Washington, D.C.   38.883333
# 234               US Virgin Islands          VI  Charlotte Amalie   18.350000
#
#      capitalLong    continentName     nationality nationality2 nationality3  \
# 55     33.366667           Europe         Cypriot          NaN          NaN
# 60    -61.400000    North America       Dominican          NaN          NaN
# 61    -69.900000    North America       Dominican          NaN          NaN
# 71    158.150000        Australia     Micronesian          NaN          NaN
# 88    -13.700000           Africa  Channel Island          NaN          NaN
# 107    -2.100000           Europe  Channel Island          NaN          NaN
# 138   106.916667             Asia     Micronesian          NaN          NaN
# 156    33.366667           Europe         Cypriot          NaN          NaN
# 197    45.333333           Africa          Somali     Somalian          NaN
# 198    44.050000           Africa          Somali     Somalian          NaN
# 231   -77.000000  Central America        American          NaN          NaN
# 233   -77.000000        Australia        American          NaN          NaN
# 234   -64.933333    North America        American          NaN          NaN
#
#     nationality4
# 55           NaN
# 60           NaN
# 61           NaN
# 71           NaN
# 88           NaN
# 107          NaN
# 138          NaN
# 156          NaN
# 197          NaN
# 198          NaN
# 231          NaN
# 233          NaN
# 234          NaN

# %% [markdown]
# Unfortunately, these records should be amended manually

# %%
# careate a list of amendments
amendments = ['Cypriot',
             'Dominican (Dominica)',
             'Dominican (Dominican Republic)',
             'Micronesian',
             'Guinean (Guinea)',
             'British (Jersey)',
             'Mongolian',
             'Cypriot (Northern Cyprus)',
             'Somalian',
             'Somalian (Somaliland)',
             'American',
             'American (US Minor Outlying Islands)',
             'American (US Virgin Islands)']

# create a dictionary of indexes and amendments
amendmentsDic = dict(zip(countries[countries['nationality'].isin(nationalityCount.index)].index.to_list(), amendments))

# print and check that everything is ok
print(amendmentsDic)
# Out:
# {55: 'Cypriot', 60: 'Dominican (Dominica)', 61: 'Dominican (Dominican Republic)', 71: 'Micronesian', 88: 'Guinean (Guinea)', 107: 'British (Jersey)', 138: 'Mongolian', 156: 'Cypriot (Northern Cyprus)', 197: 'Somalian', 198: 'Somalian (Somaliland)', 231: 'American', 233: 'American (US Minor Outlying Islands)', 234: 'American (US Virgin Islands)'}

# %%
# replace invalid nationality values
for i in amendmentsDic:
    countries.at[i,'nationality'] = amendmentsDic[i]

# %%
# did it work?
nationalityCount = countries['nationality'].value_counts()
print(nationalityCount[nationalityCount>1])
# Out:
# Series([], Name: nationality, dtype: int64)

# %%
# Manual amendments
countries.at[123,'nationality'] = 'Luxembourgish'
countries.at[149,'nationality'] = 'New Zealander'
countries.at[29,'nationality'] = 'Brazilian'
countries.at[30,'nationality'] = 'British (British Indian Ocean Territory)'
countries.at[31,'nationality'] = 'British (British Virgin Islands)'
countries.at[36,'nationality'] = 'Cambodian' 
countries.at[37,'nationality'] = 'Cameroonian'
countries.at[38,'nationality'] = 'Canadian' 
countries.at[39,'nationality'] = 'Cape Verdean' 
countries.at[173,'nationality'] = 'Congolese (Republic of Congo)'

# %% [markdown]
# #### Step 2: Identifying inconsistencies

# %%
# create a list of nationalities from the countries data set
countriesNationalityList = countries['nationality'].to_list()

# create a list of nationalities from the rawJson data set
rawJsonNationalityList = rawJson['NationalityClean'].explode().unique()

# locate inconsistencies
inconsistencies = [i for i in rawJsonNationalityList if i not in countriesNationalityList]

# remove the first element (0)
inconsistencies.remove(inconsistencies[0])

inconsistencies
# Out:
# ['Coptic',
#  'Persian',
#  'Yugoslav',
#  'Scottish',
#  'Czechoslovakian',
#  'Korean',
#  'Bosnian',
#  'Canadian Inuit',
#  'Tajik',
#  'Native American',
#  'Welsh',
#  'Catalan',
#  'Filipino',
#  'Burkinabe']

# %% [markdown]
# #### Step 3: Create an amedments dictionary

# %%
# create an amendments list
amendments = ['Egyptian',
              'Iranian',
              'Serbian',
              'British',
              'Czech',
              'South Korean',
              'Bosnian or Herzegovinian',
              'Canadian',
              'Tajikistani',
              'American',
              'British',
              'Spanish',
              'Philippine',
              'Burkinabé']

# create a dictionary of indexes and amendments
amendmentsDic = dict(zip(inconsistencies, amendments))

# %%
amendmentsDic
# Out:
# {'Coptic': 'Egyptian',
#  'Persian': 'Iranian',
#  'Yugoslav': 'Serbian',
#  'Scottish': 'British',
#  'Czechoslovakian': 'Czech',
#  'Korean': 'South Korean',
#  'Bosnian': 'Bosnian or Herzegovinian',
#  'Canadian Inuit': 'Canadian',
#  'Tajik': 'Tajikistani',
#  'Native American': 'American',
#  'Welsh': 'British',
#  'Catalan': 'Spanish',
#  'Filipino': 'Philippine',
#  'Burkinabe': 'Burkinabé'}

# %% [markdown]
# #### Step 4: Applying amendments

# %%
# define a function to replace keys with values
def replaceInvalidNationaities(nlist,ndic):
    '''This function replaces invalid nationality values by a dictionary keys'''
    output = []
    for i in nlist:
        if i in ndic:
            output.append(ndic[i])
        else:
            output.append(i)
    return output

# apply the function on the nationality column in rawJson
rawJson['NationalityCleaner'] = rawJson['NationalityClean'].apply(replaceInvalidNationaities,ndic = amendmentsDic)

# %%
# did it work?
# create a list of nationalities from the countries data set
countriesNationalityList = countries['nationality'].to_list()

# create a list of nationalities from the rawJson data set
rawJsonNationalityList = rawJson['NationalityCleaner'].explode().unique()

# locate inconsistencies
inconsistencies = [i for i in rawJsonNationalityList if i not in countriesNationalityList]

# remove the first element (0)
inconsistencies.remove(inconsistencies[0])

inconsistencies
# Out:
# []

# %% [markdown]
# ### Adding a list with country codes for each artwork

# %%
# creating a countries dictionary
countriesDic = dict(zip(countries.index.values,countries.nationality))

# %%
# defining a new function
def addCountryList(cell,dictionary):
    '''This function iterates over a list of nationalities and returns a list of country codes'''
    output = []
    for i in cell:
        try:
            output.append(list(dictionary.keys())[list(dictionary.values()).index(i)])
        except:
            pass
    return output

# applying the function on the nationality column
rawJson['nationalityCodes'] = rawJson['NationalityCleaner'].apply(addCountryList,dictionary=countriesDic)

# %% [markdown]
# ### Are there any invalid gender values?
# As we can see in the next cell, the following gender values should be removed or changed in our data set:
# - '' (empty string) - 1948 occurrences
# - male - 30 occurrences (should be replaced with 'Male')
# - female - 2 occurrences (should be replaced with 'Female')

# %%
# Gender
genderCheck = rawJson['Gender'].explode().value_counts()
print('Number of unique values: ',len(genderCheck))
print(genderCheck.to_string())
# Out:
# Number of unique values:  6
# Male          120342
# Female         21457
#                 1948
# male              30
# female             2
# Non-Binary         1

# %%
# defining a function
def cleanGender(row):
    '''This function reads each element in the gender column, drops empty strings and returns first upper case letters for each element'''
    outputList = []
    for element in row:
        if element != '':
            outputList.append(element.title())
    return outputList

# add a new column
rawJson['GenderClean'] = rawJson['Gender'].apply(cleanGender)

# %%
# Did it work?
genderCheck = rawJson['GenderClean'].explode().value_counts()
print('Number of unique values: ',len(genderCheck))
print(genderCheck.to_string())
# Out:
# Number of unique values:  3
# Male          120372
# Female         21459
# Non-Binary         1

# %% [markdown]
# ### Are there any invalid artist values?
# As we can see in the next cell, the following artist values should be removed or changed in our data set:
# - Unknown photographer - 2896 occurrences
# - Unknown Artist - 732 occurrences
# - Unknown Designer - 460 occurrences
# - Unknown Artists - 201 occurrences
# - Various Unknown Artists - 73 occurrences
# - unknown - 56 occurrences
# - Designer unknown - 32 occurrences
# - Unknown Director - 26 occurrences
# - Unknown Author - 8 occurrences
# - Unknown designer - 5 occurrences
# - Unknown Graphic Artist - 3 occurrences
# - Unknown sculptor - 1 occurrence

# %%
artistCheck = rawJson['Artist'].explode().value_counts()
print('Number of unique values: ',len(artistCheck))
print(artistCheck.to_string())
# Out:
# Number of unique values:  14628
# Eugène Atget                                                                       5050
# Louise Bourgeois                                                                   3382
# Unknown photographer                                                               2896
# Ludwig Mies van der Rohe                                                           2682
# Jean Dubuffet                                                                      1436
# Lee Friedlander                                                                    1338
# Pablo Picasso                                                                      1322
# Marc Chagall                                                                       1174
# George Maciunas                                                                    1084
# Henri Matisse                                                                      1069
# Various Artists                                                                     977
# Pierre Bonnard                                                                      909
# Frank Lloyd Wright                                                                  886
# Lilly Reich                                                                         848
# August Sander                                                                       750
# Unknown Artist                                                                      732
# Ben Kinmont                                                                         665
# Sol LeWitt                                                                          654
# János Kender                                                                        653
# Harry Shunk                                                                         653
# Georges Rouault                                                                     633
# Émile Bernard                                                                       631
# Aristide Maillol                                                                    580
# André Derain                                                                        573
# Raoul Dufy                                                                          550
# Joan Miró                                                                           506
# Maurice Denis                                                                       505
# Frédéric Bruly Bouabré                                                              483
# Dorothea Lange                                                                      479
# Unknown Designer                                                                    460
# Jan Dibbets                                                                         459
# Pierre Alechinsky                                                                   448
# Jasper Johns                                                                        433
# Jim Dine                                                                            430
# Album-miscellaneous                                                                 388
# Robert Rauschenberg                                                                 365
# Walker Evans                                                                        365
# Ben Vautier                                                                         365
# Garry Winogrand                                                                     359
# Jules Pascin                                                                        352
# Raymond Pettibon                                                                    338
# Pope.L                                                                              325
# Thomas Bewick                                                                       324
# Andy Warhol                                                                         316
# André Masson                                                                        313
# Henri Cartier-Bresson                                                               306
# Jerry Lewis                                                                         303
# John Jensen                                                                         302
# Edward Steichen                                                                     300
# Christian Boltanski                                                                 298
# Alexander Calder                                                                    297
# Josef Albers                                                                        296
# Natalia Goncharova                                                                  292
# Aleksandr Rodchenko                                                                 291
# Robert Watts                                                                        290
# Odilon Redon                                                                        290
# Ansel Adams                                                                         288
# José Antonio Suárez Londoño                                                         285
# Alighiero Boetti                                                                    284
# George Brecht                                                                       283
# André Dunoyer de Segonzac                                                           279
# Robert Motherwell                                                                   276
# Dieter Roth                                                                         267
# Eduardo Paolozzi                                                                    266
# Jacques Villon                                                                      266
# John Thomson                                                                        264
# Leonard Baskin                                                                      264
# Olga Rozanova                                                                       263
# Martin Kippenberger                                                                 261
# Edward Weston                                                                       261
# Ellsworth Kelly                                                                     260
# Antonio Frasconi                                                                    257
# Thomas Schütte                                                                      252
# Max Ernst                                                                           252
# Harry Callahan                                                                      247
# Victor Vasarely                                                                      68
# Ignacio Petchersky                                                                   68
# Rudy Pozzatti                                                                        68
# Karl Schmidt-Rottluff                                                                68
# Wolf Vostell                                                                         67
# Richard Hamilton                                                                     67
# Felipe Tarsitano                                                                     67
# George Platt Lynes                                                                   67
# Massimo Vignelli                                                                     67
# Destroy All Monsters                                                                 67
# Gerald Laing                                                                         66
# Mel Bochner                                                                          66
# Daniel Buren                                                                         66
# Paul Sharits                                                                         66
# Allen Ruppersberg                                                                    66
# George Barnard                                                                       66
# Inc.                                                                                 66
# Ian Hamilton Finlay                                                                  66
# Helen Frankenthaler                                                                  66
# Ray Eames                                                                            66
# June Wayne                                                                           66
# Rudolf Schwarzkogler                                                                 66
# Günther Förg                                                                         65
# Alfredo Zalce                                                                        65
# Margaret Bourke-White                                                                64
# Walter Richard Sickert                                                               64
# Boris Kustodiev                                                                      64
# James Brown                                                                          63
# John D. Graham                                                                       63
# Sidney Nolan                                                                         63
# Sam Francis                                                                          63
# Kelley Walker                                                                        63
# Wright Morris                                                                        63
# Bill Jensen                                                                          63
# John Armleder                                                                        62
# Mustafa Faruki                                                                       62
# Clinton Adams                                                                        62
# Max Jiménez                                                                          62
# Paul McCarthy                                                                        62
# Bruce Conner                                                                         62
# Joanne Leonard                                                                       62
# Barnett Newman                                                                       62
# Maurice Utrillo                                                                      61
# Eleanor Antin                                                                        61
# Vladimir Kozlinskii                                                                  61
# Bernard Tschumi                                                                      61
# Gilles Peress                                                                        61
# Michael Mazur                                                                        60
# Édouard Vuillard                                                                     60
# Asger Jorn                                                                           60
# Hans Bellmer                                                                         60
# Manuel Álvarez Bravo                                                                 60
# Rosalind Fox Solomon                                                                 60
# Rolf Harder                                                                          60
# Roger Vieillard                                                                      60
# Ingrid Wiener                                                                        60
# Juan Gris                                                                            60
# Edo Murtic                                                                           60
# Richard Artschwager                                                                  59
# Hugh Townley                                                                         59
# Martin Parr                                                                          59
# Sonia Delaunay-Terk                                                                  59
# Mathew B. Brady (studio of)                                                          59
# Lee Bontecou                                                                         58
# Takehisa Kosugi                                                                      58
# William Gedney                                                                       58
# Robert Heinecken                                                                     58
# Gerhard Marcks                                                                       58
# Lance Wyman                                                                          58
# Takako Saito                                                                         58
# Florine Stettheimer                                                                  57
# Enrico Baj                                                                           57
# David Shrigley                                                                       57
# Kseniia Boguslavskaia                                                                57
# James Prestini                                                                       57
# Marina Abramović                                                                     57
# George Passmore                                                                      57
# Mstislav Dobuzhinskii                                                                57
# Mira Schendel                                                                        57
# Gunta Stölzl                                                                         57
# Gilbert Proesch                                                                      57
# Ruth Asawa                                                                           56
# Robert Indiana                                                                       56
# unknown                                                                              56
# A. G. Fronzoni                                                                       56
# Juan Hidalgo                                                                         56
# Maurizio Cattelan                                                                    56
# David Shterenberg                                                                    56
# Ken Price                                                                            55
# Robert Andrew Parker                                                                 55
# Omar Rayo                                                                            55
# Billy Al Bengston                                                                    55
# José Antonio Attolini Lack                                                           55
# Elie Nadelman                                                                        55
# Dan Weiner                                                                           55
# Robert Gober                                                                         55
# Mario Merz                                                                           55
# Juan Manuel Echavarría                                                                1
# Berto Lardera                                                                         1
# Noah Purifoy                                                                          1
# Zhijun Wang                                                                           1
# Hap Tivey                                                                             1
# Converse                                                                              1
# Doris Dorrie                                                                          1
# Han Schuil                                                                            1
# Mowry Thatcher Baden                                                                  1
# Rodolfo (Rodolfo Mishaan Pinto) Mishaan                                               1
# Silicon Systems                                                                       1
# Vincent Patar                                                                         1
# Peter Callas                                                                          1
# Venna                                                                                 1
# Eva Björklund                                                                         1
# Kunié Sugiura                                                                         1
# Robert Gretczko                                                                       1
# Hervé Guibert                                                                         1
# Dorothy Ruddick                                                                       1
# Stano Filko                                                                           1
# Hans Sahl                                                                             1
# Robert Pasut                                                                          1
# Nikolai Aseev                                                                         1
# Paul Schudel                                                                          1
# Ben Katchor                                                                           1
# Zdravko Tisljar                                                                       1
# Howard Head                                                                           1
# Matthias Hoch                                                                         1
# Rogelio París                                                                        1
# Lloyd de Mause                                                                        1
# Peter L. Zane                                                                         1
# Anna Ostroumova-Lebedeva                                                              1
# Herman Landshoff                                                                      1
# Sven Lukin                                                                            1
# Paul Sparks                                                                           1
# Takaaki Okada                                                                         1
# Miljenko Horvat                                                                       1
# Stephan Rosenthal                                                                     1
# Leo Gerstenzang                                                                       1
# Marcello Boccacci                                                                     1
# Vittorio Tavernari                                                                    1
# Karel Maes                                                                            1
# Jeroen Verhoeven                                                                      1
# Tom DeFanti                                                                           1
# T. R. Uthco                                                                           1
# American Mutoscope and Biograph Company                                               1
# Volkmar K. Wentzel                                                                    1
# René Brô                                                                              1
# Ines Lombardi                                                                         1
# Paul Renner                                                                           1
# Hal Woolf                                                                             1
# O Meul                                                                                1
# Marcus Carius                                                                         1
# Melanie Smith                                                                         1
# Jørgen Haugen Sørensen                                                                1
# Pedro Manrique Figueroa                                                               1
# Charles Roitz                                                                         1
# A. Gisiger                                                                            1
# Arthur Emil Bofinger                                                                  1
# Linda Lindeberg                                                                       1
# Gerard Huerta                                                                         1
# Edmund Edel                                                                           1
# Argentina                                                                             1
# Bezalel Academy of Art and Design                                                     1
# Olga Chernysheva                                                                      1
# David Mayor                                                                           1
# Lorenzo Goñi                                                                          1
# Louis L. Lepoix                                                                       1
# Eddie Ruscha                                                                          1
# Mark Sanders                                                                          1
# Jasmila Žbanić                                                                        1
# Stanley Kubrick                                                                       1
# Christophe Cornubert                                                                  1

# %%
# locate invalid values
invalidArtistValues = artistCheck.index[artistCheck.index.str.contains('nknown')].to_series()

# %%
# removing invalid artist values
rawJson['ArtistClean'] = rawJson['Artist'].apply(
    lambda row: [val for val in row if val not in invalidArtistValues]   
)

# %%
# did it work?
artistCheck = rawJson['ArtistClean'].explode().value_counts()
artistCheck.index[artistCheck.index.str.contains('nknown')]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ### Are there any invalid ThumbnailURL values?

# %%
# calling and applying the url function from the validators to validate the thumbnail urls
def urlValidator(value):
    '''This function validates url strings, and returns True for valid urls and False for invalid'''
    valueCheck = validators.url(str(value))
    if type(valueCheck) == validators.utils.ValidationFailure:
        return False
    else:
        return True
    
# adding a new column
rawJson['isValidThumbnailURL'] = rawJson.ThumbnailURL.apply(urlValidator)

# did it work?
rawJson['isValidThumbnailURL'].value_counts()
# Out:
# True     73969
# False    65021
# Name: isValidThumbnailURL, dtype: int64

# %%
# who are the invalid urls?
rawJson.loc[(rawJson['isValidThumbnailURL'] == False),['ThumbnailURL','isValidThumbnailURL']].sample(100)
# Out:
#        ThumbnailURL  isValidThumbnailURL
# 39040          None                False
# 30180          None                False
# 23717          None                False
# 102387         None                False
# 112951         None                False
# ...             ...                  ...
# 16480          None                False
# 115219         None                False
# 35010          None                False
# 27559          None                False
# 44748          None                False
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Are there any invalid artwork URL values?

# %%
# adding a new column
rawJson['isValidURL'] = rawJson.URL.apply(urlValidator)

# did it work?
rawJson['isValidURL'].value_counts()
# Out:
# True     84249
# False    54741
# Name: isValidURL, dtype: int64

# %% [markdown]
# ## Reformatting the year column
# We'll add a new column that represents the year when the artwork has been accomplished.

# %%
def tidyDate(value):
    '''this function reads a string that represents a range of years and returns the later year as an integer'''
    pattern = re.compile(r'[12][0789]\d\d[-–]?\d{0,4}|\d{1,2}[rt][dh]')
    p1 = re.compile(r'[12][0789]\d\d[-–][12][0789]\d\d')
    p2 = re.compile(r'[12][0789]\d\d[-–]\d\d\b')
    p3 = re.compile(r'[12][0789]\d\d[-–]\D')
    result = pattern.findall(str(value))
    output = []
    for i in result:
        if re.match(p1,i):
            output.append(int(i[-4:]))
        else:
            if re.match(p2,i):
                output.append(int(i[:2]+i[-2:]))
            else:     
                if re.match(p3,i):
                    output.append(int(i[:4]))
                else:
                    if len(i) == 4:
                        try:
                            output.append(int(i))
                        except:
                            pass
                    
    if len(output) == 0 or result == None:
        return 0
    else:
        return max(output)
    
# applying the function on the date column
rawJson['tidyDate'] = rawJson['Date'].apply(tidyDate)

# %%
# applying the function on the tidy date column
rawJson['Decade'] = (rawJson['tidyDate'].apply(lambda year: str(year)[:3]+'0' if len(str(year))==4 else 0)).astype('category')

# %%
rawJson['Decade'].value_counts()
# Out:
# 1960    21229
# 1970    16163
# 1930    11389
# 1920    11173
# 1940    11046
# 2000    10888
# 1950    10827
# 1980    10754
# 1990    10185
# 1910     7024
# 1900     4869
# 2010     3956
# 0        3425
# 1890     2179
# 1860     1040
# 1870      887
# 1850      763
# 1880      531
# 1810      327
# 1840      216
# 1790       81
# 1820       20
# 1830       10
# 1760        5
# 1800        3
# Name: Decade, dtype: int64

# %% [markdown]
# ## Calculating the number of nationalities, artists and genders for each artwork

# %%
# using lambda functions
rawJson['numOfNationalities'] = rawJson['NationalityCleaner'].apply(lambda x: len(x))
rawJson['numOfArtists'] = rawJson['ArtistClean'].apply(lambda x: len(x))
rawJson['numOfGenders'] = rawJson['GenderClean'].apply(lambda x: len(x))

# %% [markdown]
# ## Exporting a subset for valid artworks
# Valid artworks have:
# * no missing nationality values
# * no missing artist names
# * same number of elements in the nationality, artist and gender fields
# * valid thumbnail url
# * valid url
# * valid date
# * marked as curator approved

# %%
# setting the column for export
keptColumns = ['Title',
               'Artist',
               'NationalityCleaner',
               'nationalityCodes',
               'Classification',
               'tidyDate',
               'Decade',
               'GenderClean',
               'Medium',
               'ThumbnailURL',
               'ConstituentID',
               'ObjectID',
               'AccessionNumber',
               'URL']

# creating a subset
export = rawJson.loc[(rawJson['Cataloged'] == 'Y') &
                     (rawJson['tidyDate'] != 0) &
                     (rawJson['isValidURL'] == True) &
                     (rawJson['isValidThumbnailURL'] == True) &
                     (rawJson['numOfNationalities'] != 0) &
                     (rawJson['numOfArtists'] != 0) &
                     (rawJson['numOfGenders'] != 0) &
                     (rawJson['numOfArtists'] == rawJson['numOfNationalities']) &
                     (rawJson['numOfArtists'] == rawJson['numOfGenders']) &
                     (rawJson['numOfNationalities'] == rawJson['numOfGenders']),
                     keptColumns]

#Changing the index name
export.index.name = 'FID'

# reset the index
export = export.reset_index()

# print shape
print('The new subset contains ', str(export.shape[0]), 'artworks.')

# take a look
export.head()
# Out:
# The new subset contains  68320 artworks.
#    FID                                              Title  \
# 0    0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1    1  City of Music, National Superior Conservatory ...
# 2    2  Villa near Vienna Project, Outside Vienna, Aus...
# 3    4  Villa, project, outside Vienna, Austria, Exter...
# 4   30  Memorial to the Six Million Jewish Martyrs, pr...
#
#                        Artist NationalityCleaner nationalityCodes  \
# 0               [Otto Wagner]         [Austrian]             [14]
# 1  [Christian de Portzamparc]           [French]             [74]
# 2                [Emil Hoppe]         [Austrian]             [14]
# 3                [Emil Hoppe]         [Austrian]             [14]
# 4             [Louis I. Kahn]         [American]            [231]
#
#   Classification  tidyDate Decade GenderClean  \
# 0   Architecture      1896   1890      [Male]
# 1   Architecture      1987   1980      [Male]
# 2   Architecture      1903   1900      [Male]
# 3   Architecture      1903   1900      [Male]
# 4   Architecture      1968   1960      [Male]
#
#                                               Medium  \
# 0      Ink and cut-and-pasted painted pages on paper
# 1                  Paint and colored pencil on print
# 2  Graphite, pen, color pencil, ink, and gouache ...
# 3  Graphite, color pencil, ink, and gouache on tr...
# 4             Charcoal and graphite on tracing paper
#
#                                         ThumbnailURL ConstituentID  ObjectID  \
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...        [6210]         2
# 1  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...        [7470]         3
# 2  http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...        [7605]         4
# 3  http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...        [7605]         6
# 4  http://www.moma.org/media/W1siZiIsIjE3MyJdLFsi...        [2964]        32
#
#   AccessionNumber                                      URL
# 0        885.1996   http://www.moma.org/collection/works/2
# 1          1.1995   http://www.moma.org/collection/works/3
# 2          1.1997   http://www.moma.org/collection/works/4
# 3          2.1997   http://www.moma.org/collection/works/6
# 4          3.1997  http://www.moma.org/collection/works/32

# %% [markdown]
# # Exporting the subset to a JSON file

# %%
# export the artworks data frame
export.to_json('CleanedDataJG.json',orient='records')

# %%
# export the countries data frame
countriesExport = countries.iloc[:,0:7]
countriesExport.to_json('CleanCountries.json',orient = 'records')
